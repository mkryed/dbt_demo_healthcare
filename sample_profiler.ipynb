# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

# %%
# number of rows in the set
pd.read_gbq("SELECT COUNT(*) FROM bigquery-public-data.fhir_synthea.practitioner")
# Out:
# /Users/anthony.lui/Library/Caches/pypoetry/virtualenvs/dbt-demo-healthcare-9M_nQ_Yl-py3.11/lib/python3.11/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#    f0_
# 0  129

# %%
df = pd.read_gbq("SELECT * FROM bigquery-public-data.fhir_synthea.practitioner")
df.head()
# Out:
#   birthDate communication implicitRules language  meta photo qualification  \
# 0      None            []          None     None  None    []            []
# 1      None            []          None     None  None    []            []
# 2      None            []          None     None  None    []            []
# 3      None            []          None     None  None    []            []
# 4      None            []          None     None  None    []            []
#
#   telecom  text  active                                            address  \
# 0      []  None    True  [{'district': None, 'period': None, 'text': No...
# 1      []  None    True  [{'district': None, 'period': None, 'text': No...
# 2      []  None    True  [{'district': None, 'period': None, 'text': No...
# 3      []  None    True  [{'district': None, 'period': None, 'text': No...
# 4      []  None    True  [{'district': None, 'period': None, 'text': No...
#
#   gender                                    id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   birthDate      0 non-null      object
#  1   communication  129 non-null    object
#  2   implicitRules  0 non-null      object
#  3   language       0 non-null      object
#  4   meta           0 non-null      object
#  5   photo          129 non-null    object
#  6   qualification  129 non-null    object
#  7   telecom        129 non-null    object
#  8   text           0 non-null      object
#  9   active         129 non-null    boolean
#  10  address        129 non-null    object
#  11  gender         129 non-null    object
#  12  id             129 non-null    object
#  13  identifier     129 non-null    object
#  14  name           129 non-null    object
# dtypes: boolean(1), object(14)
# memory usage: 14.5+ KB

# %%
profile = ProfileReport(df)

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.2.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-06-02 20:19:49.850676&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
